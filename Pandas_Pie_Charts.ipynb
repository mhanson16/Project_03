# %%
import pandas as pd 
import matplotlib as plt
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import numpy as np
from matplotlib import pyplot as plt

# %%
# Reading the csv file
df_new = pd.read_csv('Initial_Data/GCB2022v27_percapita_flat.csv')
df_new
# Out:
#            Country ISO 3166-1 alpha-3  Year     Total      Coal       Oil  \
# 0      Afghanistan                AFG  1750       NaN       NaN       NaN
# 1      Afghanistan                AFG  1751       NaN       NaN       NaN
# 2      Afghanistan                AFG  1752       NaN       NaN       NaN
# 3      Afghanistan                AFG  1753       NaN       NaN       NaN
# 4      Afghanistan                AFG  1754       NaN       NaN       NaN
# ...            ...                ...   ...       ...       ...       ...
# 63099       Global                WLD  2017  4.749682  1.908857  1.610910
# 63100       Global                WLD  2018  4.792753  1.919213  1.596350
# 63101       Global                WLD  2019  4.775633  1.896468  1.589920
# 63102       Global                WLD  2020  4.497423  1.807760  1.427353
# 63103       Global                WLD  2021  4.693699  1.893923  1.496614
#
#             Gas    Cement   Flaring     Other
# ...

# %%
# saving xlsx file
GFG = pd.ExcelWriter('PF_Files/GCB2022v27_percapita_flat.xlsx')
df_new.to_excel(GFG, index=False)
GFG.save()

# %%
#Biggest Contributiors of CO2 Emission by Coal

Coal_df_new = df_new[["Country","Coal", "Year","Total"]] 
top_Coal_df_new= Coal_df_new.nlargest(5, 'Coal')
top_Coal_df_new
Coal_title = 'CO2 Emissions caused by Coal'
top_Coal_df_new.groupby(['Year','Country', 'Total']).sum().plot(kind='pie',y='Coal',fontsize=6, shadow=True,label="", figsize=(2,2),title = Coal_title, autopct='%1.0f%%', legend = None,explode = (0, 0, 0.10, 0, 0) )
# Out:
# <AxesSubplot:title={'center':'CO2 Emissions caused by Coal'}>

# %%
#Biggest Contributiors of CO2 Emission by Oil

Oil_df_new = df_new[["Country","Oil", "Year","Total"]] 
top_Oil_df_new= Oil_df_new.nlargest(5, 'Oil')
top_Oil_df_new
Oil_title = 'CO2 Emissions caused by Oil'
top_Oil_df_new.groupby([ 'Country','Year','Total',]).sum().plot(kind='pie',y=('Oil'),fontsize=6, shadow=True,label="", figsize=(2,2),title = Oil_title, autopct='%1.0f%%', legend = None,explode = (0, 0.10, 0, 0, 0) )
# Out:
# <AxesSubplot:title={'center':'CO2 Emissions caused by Oil'}>

# %%
#Biggest Contributiors of CO2 Emission by Gas

Gas_df_new = df_new[["Country","Gas", "Year","Total"]] 
top_Gas_df_new= Gas_df_new.nlargest(5, 'Gas')
top_Gas_df_new
Gas_title = 'CO2 Emissions caused by Gas'
top_Gas_df_new.groupby(['Year','Country', 'Total']).sum().plot(kind='pie',y='Gas',fontsize=6, shadow=True,label="", figsize=(2,2),title = Gas_title, autopct='%1.0f%%', legend = None,explode = (0.10, 0, 0, 0, 0) )
# Out:
# <AxesSubplot:title={'center':'CO2 Emissions caused by Gas'}>

# %%
#Biggest Contributiors of CO2 Emission by Flaring

Flaring_df_new = df_new[["Country","Flaring", "Year","Total"]] 
top_Flaring_df_new= Flaring_df_new.nlargest(5, 'Flaring')
top_Flaring_df_new
Flaring_title = 'CO2 Emissions caused by Flaring'
top_Flaring_df_new.groupby(['Year','Country', 'Total']).sum().plot(kind='pie',y='Flaring',fontsize=6, shadow=True,label="", figsize=(2,2),title = Flaring_title, autopct='%1.0f%%', legend = None,explode = (0, 0.10, 0, 0, 0) )
# Out:
# <AxesSubplot:title={'center':'CO2 Emissions caused by Flaring'}>

# %%
#Biggest Contributiors of CO2 Emission by Cement

Cement_df_new = df_new[["Country","Cement", "Year","Total"]] 
top_Cement_df_new= Cement_df_new.nlargest(5, 'Cement')
top_Cement_df_new
Cement_title = 'CO2 Emmissions caused by Cement'
top_Cement_df_new.groupby(['Year','Country', 'Total']).sum().plot(kind='pie',y='Cement',fontsize=6, shadow=True,label="", figsize=(2,2),title = Cement_title, autopct='%1.0f%%', legend = None,explode = (0, 0, 0, 0.10, 0) )
# Out:
# <AxesSubplot:title={'center':'CO2 Emmissions caused by Cement'}>
