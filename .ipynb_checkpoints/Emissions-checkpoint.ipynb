# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
import json

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that the "emissions" database is in MongoDB
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'emissions', 'epa', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'uk_food']

# %%
# assign the database to a variable name
db = mongo['emissions']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['countries']

# %%
# assign each collection to a variable
countries = db['countries']

# %%
# Create a query that finds emissions before 1945 to check if rows were deleted from shell
query = {'Year': {'$lt': '1945'}}
results = countries.find(query)
for result in results:
    print(result)

# %%
# Create a query that finds the country French Equatorial Africa to see if ISO was updated from shell
query = {'Country': 'French Equatorial Africa'}

# Capture the results to a variable
results = countries.find(query)

# Pretty print the first result
for i in range(1):
    pprint(results[i])
# Out:
# {'Cement': '',
#  'Coal': '',
#  'Country': 'French Equatorial Africa',
#  'Flaring': '',
#  'Gas': '',
#  'ISO': 'FEA',
#  'Oil': '',
#  'Other': '',
#  'Total': '',
#  'Year': '1945',
#  '_id': ObjectId('64273cf7cfb518dff1f26bac')}

# %%
# Create a query that finds the country Curacao to see if country name was updated from shell
query = {'Country': 'Curacao'}

# Capture the results to a variable
results = countries.find(query)

# Pretty print the first two results
for i in range(2):
    pprint(results[i])
# Out:
# {'Cement': '',
#  'Coal': '',
#  'Country': 'Curacao',
#  'Flaring': '',
#  'Gas': '',
#  'ISO': 'CUW',
#  'Oil': '',
#  'Other': '',
#  'Total': '',
#  'Year': '1945',
#  '_id': ObjectId('64273cf6cfb518dff1f2544c')}
# {'Cement': '',
#  'Coal': '',
#  'Country': 'Curacao',
#  'Flaring': '',
#  'Gas': '',
#  'ISO': 'CUW',
#  'Oil': '',
#  'Other': '',
#  'Total': '',
#  'Year': '1946',
#  '_id': ObjectId('64273cf6cfb518dff1f2544d')}

# %%
#count documents
countries.count_documents({})
# Out:
# 17864

# %%
#limit to data from past 5 years
query = {'Year': {'$gte': '2017'}}
results = countries.find(query)
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('64273cf6cfb518dff1f22084'), 'Country': 'Afghanistan', 'Year': '2017', 'Total': '0.276852', 'Coal': '0.096731', 'Oil': '0.170436', 'Gas': '0.008429', 'Cement': '0.001256', 'Flaring': '0', 'Other': '', 'ISO': 'AFG'}
# {'_id': ObjectId('64273cf6cfb518dff1f22085'), 'Country': 'Afghanistan', 'Year': '2018', 'Total': '0.294876', 'Coal': '0.104866', 'Oil': '0.180470', 'Gas': '0.007990', 'Cement': '0.001550', 'Flaring': '0', 'Other': '', 'ISO': 'AFG'}
# {'_id': ObjectId('64273cf6cfb518dff1f22086'), 'Country': 'Afghanistan', 'Year': '2019', 'Total': '0.293401', 'Coal': '0.104708', 'Oil': '0.181177', 'Gas': '0.006502', 'Cement': '0.001015', 'Flaring': '0', 'Other': '', 'ISO': 'AFG'}
# {'_id': ObjectId('64273cf6cfb518dff1f22087'), 'Country': 'Afghanistan', 'Year': '2020', 'Total': '0.299746', 'Coal': '0.106488', 'Oil': '0.185254', 'Gas': '0.006447', 'Cement': '0.001557', 'Flaring': '0', 'Other': '', 'ISO': 'AFG'}
# {'_id': ObjectId('64273cf6cfb518dff1f22088'), 'Country': 'Afghanistan', 'Year': '2021', 'Total': '0.296119', 'Coal': '0.104828', 'Oil': '0.185029', 'Gas': '0.005956', 'Cement': '0.000306', 'Flaring': '0', 'Other': '', 'ISO': 'AFG'}
# {'_id': ObjectId('64273cf6cfb518dff1f22194'), 'Country': 'Albania', 'Year': '2017', 'Total': '1.932429', 'Coal': '0.095372', 'Oil': '1.416589', 'Gas': '0.058495', 'Cement': '0.351291', 'Flaring': '0.010682', 'Other': '', 'ISO': 'ALB'}
# {'_id': ObjectId('64273cf6cfb518dff1f22195'), 'Country': 'Albania', 'Year': '2018', 'Total': '1.732368', 'Coal': '0.164287', 'Oil': '1.157651', 'Gas': '0.052215', 'Cement': '0.353399', 'Flaring': '0.004816', 'Other': '', 'ISO': 'ALB'}
# {'_id': ObjectId('64273cf6cfb518dff1f22196'), 'Country': 'Albania', 'Year': '2019', 'Total': '1.721533', 'Coal': '0.112194', 'Oil': '1.197159', 'Gas': '0.045897', 'Cement': '0.364726', 'Flaring': '0.001557', 'Other': '', 'ISO': 'ALB'}
# {'_id': ObjectId('64273cf6cfb518dff1f22197'), 'Country': 'Albania', 'Year': '2020', 'Total': '1.649392', 'Coal': '0.115611', 'Oil': '1.122339', 'Gas': '0.045757', 'Cement': '0.365620', 'Flaring': '0.000066', 'Other': '', 'ISO': 'ALB'}
# {'_id': ObjectId('64273cf6cfb518dff1f22198'), 'Country': 'Albania', 'Year': '2021', 'Total': '1.618066', 'Coal': '0.061096', 'Oil': '1.137164', 'Gas': '0.052631', 'Cement': '0.367175', 'Flaring': '0', 'Other': '', 'ISO': 'ALB'}
# {'_id': ObjectId('64273cf6cfb518dff1f222a4'), 'Country': 'Algeria', 'Year': '2017', 'Total': '4.045341', 'Coal': '0.019328', 'Oil': '1.344500', 'Gas': '2.001920', 'Cement': '0.277278', 'Flaring': '0.402316', 'Other': '', 'ISO': 'DZA'}
# {'_id': ObjectId('64273cf6cfb518dff1f222a5'), 'Country': 'Algeria', 'Year': '2018', 'Total': '4.147961', 'Coal': '0.031722', 'Oil': '1.309946', 'Gas': '2.120033', 'Cement': '0.295315', 'Flaring': '0.390946', 'Other': '', 'ISO': 'DZA'}
# {'_id': ObjectId('64273cf6cfb518dff1f222a6'), 'Country': 'Algeria', 'Year': '2019', 'Total': '4.203332', 'Coal': '0.025653', 'Oil': '1.385251', 'Gas': '2.136732', 'Cement': '0.258235', 'Flaring': '0.397461', 'Other': '', 'ISO': 'DZA'}
# {'_id': ObjectId('64273cf6cfb518dff1f222a7'), 'Country': 'Algeria', 'Year': '2020', 'Total': '3.970031', 'Coal': '0.025282', 'Oil': '1.255190', 'Gas': '2.032334', 'Cement': '0.253800', 'Flaring': '0.403426', 'Other': '', 'ISO': 'DZA'}
# {'_id': ObjectId('64273cf6cfb518dff1f222a8'), 'Country': 'Algeria', 'Year': '2021', 'Total': '3.989977', 'Coal': '0.024798', 'Oil': '1.268066', 'Gas': '2.100412', 'Cement': '0.249628', 'Flaring': '0.347072', 'Other': '', 'ISO': 'DZA'}
# {'_id': ObjectId('64273cf6cfb518dff1f223b4'), 'Country': 'Andorra', 'Year': '2017', 'Total': '6.302098', 'Coal': '0', 'Oil': '6.302098', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'AND'}
# {'_id': ObjectId('64273cf6cfb518dff1f223b5'), 'Country': 'Andorra', 'Year': '2018', 'Total': '6.594057', 'Coal': '0', 'Oil': '6.594057', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'AND'}
# {'_id': ObjectId('64273cf6cfb518dff1f223b6'), 'Country': 'Andorra', 'Year': '2019', 'Total': '6.287204', 'Coal': '0', 'Oil': '6.287204', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'AND'}
# {'_id': ObjectId('64273cf6cfb518dff1f223b7'), 'Country': 'Andorra', 'Year': '2020', 'Total': '5.777148', 'Coal': '0', 'Oil': '5.777148', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'AND'}
# {'_id': ObjectId('64273cf6cfb518dff1f223b8'), 'Country': 'Andorra', 'Year': '2021', 'Total': '5.730292', 'Coal': '0', 'Oil': '5.730292', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'AND'}
# {'_id': ObjectId('64273cf6cfb518dff1f224c4'), 'Country': 'Angola', 'Year': '2017', 'Total': '0.804541', 'Coal': '0', 'Oil': '0.483036', 'Gas': '0.052027', 'Cement': '0.032966', 'Flaring': '0.236512', 'Other': '', 'ISO': 'AGO'}
# {'_id': ObjectId('64273cf6cfb518dff1f224c5'), 'Country': 'Angola', 'Year': '2018', 'Total': '0.728395', 'Coal': '0', 'Oil': '0.475601', 'Gas': '0.051426', 'Cement': '0.033454', 'Flaring': '0.167915', 'Other': '', 'ISO': 'AGO'}
# {'_id': ObjectId('64273cf6cfb518dff1f224c6'), 'Country': 'Angola', 'Year': '2019', 'Total': '0.674362', 'Coal': '0', 'Oil': '0.429439', 'Gas': '0.075084', 'Cement': '0.034733', 'Flaring': '0.135106', 'Other': '', 'ISO': 'AGO'}
# {'_id': ObjectId('64273cf6cfb518dff1f224c7'), 'Country': 'Angola', 'Year': '2020', 'Total': '0.606541', 'Coal': '0', 'Oil': '0.391980', 'Gas': '0.075982', 'Cement': '0.033616', 'Flaring': '0.104963', 'Other': '', 'ISO': 'AGO'}
# {'_id': ObjectId('64273cf6cfb518dff1f224c8'), 'Country': 'Angola', 'Year': '2021', 'Total': '0.619141', 'Coal': '0', 'Oil': '0.402904', 'Gas': '0.085536', 'Cement': '0.032568', 'Flaring': '0.098133', 'Other': '', 'ISO': 'AGO'}
# {'_id': ObjectId('64273cf6cfb518dff1f225d4'), 'Country': 'Anguilla', 'Year': '2017', 'Total': '9.516883', 'Coal': '0', 'Oil': '9.516883', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'AIA'}
# {'_id': ObjectId('64273cf6cfb518dff1f225d5'), 'Country': 'Anguilla', 'Year': '2018', 'Total': '9.412819', 'Coal': '0', 'Oil': '9.412819', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'AIA'}
# {'_id': ObjectId('64273cf6cfb518dff1f225d6'), 'Country': 'Anguilla', 'Year': '2019', 'Total': '10.005722', 'Coal': '0', 'Oil': '10.005722', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'AIA'}
# {'_id': ObjectId('64273cf6cfb518dff1f225d7'), 'Country': 'Anguilla', 'Year': '2020', 'Total': '8.430535', 'Coal': '0', 'Oil': '8.430535', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'AIA'}
# {'_id': ObjectId('64273cf6cfb518dff1f225d8'), 'Country': 'Anguilla', 'Year': '2021', 'Total': '9.188354', 'Coal': '0', 'Oil': '9.188354', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'AIA'}
# {'_id': ObjectId('64273cf6cfb518dff1f226e4'), 'Country': 'Antarctica', 'Year': '2017', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'ATA'}
# {'_id': ObjectId('64273cf6cfb518dff1f226e5'), 'Country': 'Antarctica', 'Year': '2018', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'ATA'}
# {'_id': ObjectId('64273cf6cfb518dff1f226e6'), 'Country': 'Antarctica', 'Year': '2019', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'ATA'}
# {'_id': ObjectId('64273cf6cfb518dff1f226e7'), 'Country': 'Antarctica', 'Year': '2020', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'ATA'}
# {'_id': ObjectId('64273cf6cfb518dff1f226e8'), 'Country': 'Antarctica', 'Year': '2021', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'ATA'}
# {'_id': ObjectId('64273cf6cfb518dff1f227f4'), 'Country': 'Antigua and Barbuda', 'Year': '2017', 'Total': '5.388294', 'Coal': '0', 'Oil': '5.388294', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'ATG'}
# {'_id': ObjectId('64273cf6cfb518dff1f227f5'), 'Country': 'Antigua and Barbuda', 'Year': '2018', 'Total': '5.438456', 'Coal': '0', 'Oil': '5.438456', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'ATG'}
# {'_id': ObjectId('64273cf6cfb518dff1f227f6'), 'Country': 'Antigua and Barbuda', 'Year': '2019', 'Total': '5.409468', 'Coal': '0', 'Oil': '5.409468', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'ATG'}
# {'_id': ObjectId('64273cf6cfb518dff1f227f7'), 'Country': 'Antigua and Barbuda', 'Year': '2020', 'Total': '4.591351', 'Coal': '0', 'Oil': '4.591351', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'ATG'}
# {'_id': ObjectId('64273cf6cfb518dff1f227f8'), 'Country': 'Antigua and Barbuda', 'Year': '2021', 'Total': '5.027895', 'Coal': '0', 'Oil': '5.027895', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'ATG'}
# {'_id': ObjectId('64273cf6cfb518dff1f22904'), 'Country': 'Argentina', 'Year': '2017', 'Total': '4.242436', 'Coal': '0.097140', 'Oil': '1.835349', 'Gas': '2.189145', 'Cement': '0.099015', 'Flaring': '0.021787', 'Other': '', 'ISO': 'ARG'}
# {'_id': ObjectId('64273cf6cfb518dff1f22905'), 'Country': 'Argentina', 'Year': '2018', 'Total': '4.066307', 'Coal': '0.098087', 'Oil': '1.674990', 'Gas': '2.164272', 'Cement': '0.098364', 'Flaring': '0.030594', 'Other': '', 'ISO': 'ARG'}
# {'_id': ObjectId('64273cf6cfb518dff1f22906'), 'Country': 'Argentina', 'Year': '2019', 'Total': '3.989486', 'Coal': '0.047903', 'Oil': '1.672753', 'Gas': '2.136715', 'Cement': '0.092544', 'Flaring': '0.039571', 'Other': '', 'ISO': 'ARG'}
# {'_id': ObjectId('64273cf6cfb518dff1f22907'), 'Country': 'Argentina', 'Year': '2020', 'Total': '3.758384', 'Coal': '0.058674', 'Oil': '1.574577', 'Gas': '2.003119', 'Cement': '0.077904', 'Flaring': '0.044110', 'Other': '', 'ISO': 'ARG'}
# {'_id': ObjectId('64273cf6cfb518dff1f22908'), 'Country': 'Argentina', 'Year': '2021', 'Total': '4.117967', 'Coal': '0.106371', 'Oil': '1.773737', 'Gas': '2.083353', 'Cement': '0.103160', 'Flaring': '0.051346', 'Other': '', 'ISO': 'ARG'}
# {'_id': ObjectId('64273cf6cfb518dff1f22a14'), 'Country': 'Armenia', 'Year': '2017', 'Total': '1.942603', 'Coal': '0.001286', 'Oil': '0.304689', 'Gas': '1.564582', 'Cement': '0.072046', 'Flaring': '0', 'Other': '', 'ISO': 'ARM'}
# {'_id': ObjectId('64273cf6cfb518dff1f22a15'), 'Country': 'Armenia', 'Year': '2018', 'Total': '2.053823', 'Coal': '0.001292', 'Oil': '0.291926', 'Gas': '1.649510', 'Cement': '0.111096', 'Flaring': '0', 'Other': '', 'ISO': 'ARM'}
# {'_id': ObjectId('64273cf6cfb518dff1f22a16'), 'Country': 'Armenia', 'Year': '2019', 'Total': '2.227932', 'Coal': '0.003897', 'Oil': '0.370219', 'Gas': '1.732884', 'Cement': '0.120932', 'Flaring': '0', 'Other': '', 'ISO': 'ARM'}
# {'_id': ObjectId('64273cf6cfb518dff1f22a17'), 'Country': 'Armenia', 'Year': '2020', 'Total': '2.292074', 'Coal': '0.003863', 'Oil': '0.327806', 'Gas': '1.838826', 'Cement': '0.121579', 'Flaring': '0', 'Other': '', 'ISO': 'ARM'}
# {'_id': ObjectId('64273cf6cfb518dff1f22a18'), 'Country': 'Armenia', 'Year': '2021', 'Total': '2.438591', 'Coal': '0.004473', 'Oil': '0.355273', 'Gas': '1.956629', 'Cement': '0.122216', 'Flaring': '0', 'Other': '', 'ISO': 'ARM'}
# {'_id': ObjectId('64273cf6cfb518dff1f22b24'), 'Country': 'Aruba', 'Year': '2017', 'Total': '8.444238', 'Coal': '0', 'Oil': '8.444238', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'ABW'}
# {'_id': ObjectId('64273cf6cfb518dff1f22b25'), 'Country': 'Aruba', 'Year': '2018', 'Total': '8.229667', 'Coal': '0', 'Oil': '8.229667', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'ABW'}
# {'_id': ObjectId('64273cf6cfb518dff1f22b26'), 'Country': 'Aruba', 'Year': '2019', 'Total': '8.571203', 'Coal': '0', 'Oil': '8.571203', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'ABW'}
# {'_id': ObjectId('64273cf6cfb518dff1f22b27'), 'Country': 'Aruba', 'Year': '2020', 'Total': '7.308293', 'Coal': '0', 'Oil': '7.308293', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'ABW'}
# {'_id': ObjectId('64273cf6cfb518dff1f22b28'), 'Country': 'Aruba', 'Year': '2021', 'Total': '8.054722', 'Coal': '0', 'Oil': '8.054722', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'ABW'}
# {'_id': ObjectId('64273cf6cfb518dff1f22c34'), 'Country': 'Australia', 'Year': '2017', 'Total': '16.850455', 'Coal': '7.194136', 'Oil': '5.671368', 'Gas': '3.099259', 'Cement': '0.122774', 'Flaring': '0.604361', 'Other': '0.158558', 'ISO': 'AUS'}
# {'_id': ObjectId('64273cf6cfb518dff1f22c35'), 'Country': 'Australia', 'Year': '2018', 'Total': '16.665199', 'Coal': '6.780453', 'Oil': '5.753275', 'Gas': '3.180032', 'Cement': '0.117769', 'Flaring': '0.677588', 'Other': '0.156082', 'ISO': 'AUS'}
# {'_id': ObjectId('64273cf6cfb518dff1f22c36'), 'Country': 'Australia', 'Year': '2019', 'Total': '16.419679', 'Coal': '6.486179', 'Oil': '5.642777', 'Gas': '3.221720', 'Cement': '0.119869', 'Flaring': '0.796589', 'Other': '0.152544', 'ISO': 'AUS'}
# {'_id': ObjectId('64273cf6cfb518dff1f22c37'), 'Country': 'Australia', 'Year': '2020', 'Total': '15.579327', 'Coal': '6.082697', 'Oil': '5.277601', 'Gas': '3.290666', 'Cement': '0.109862', 'Flaring': '0.672876', 'Other': '0.145626', 'ISO': 'AUS'}
# {'_id': ObjectId('64273cf6cfb518dff1f22c38'), 'Country': 'Australia', 'Year': '2021', 'Total': '15.091473', 'Coal': '5.823767', 'Oil': '5.368438', 'Gas': '2.979896', 'Cement': '0.108798', 'Flaring': '0.666359', 'Other': '0.144215', 'ISO': 'AUS'}
# {'_id': ObjectId('64273cf6cfb518dff1f22d44'), 'Country': 'Austria', 'Year': '2017', 'Total': '7.910526', 'Coal': '1.593994', 'Oil': '3.926838', 'Gas': '2.043153', 'Cement': '0.194418', 'Flaring': '0.015714', 'Other': '0.136409', 'ISO': 'AUT'}
# {'_id': ObjectId('64273cf6cfb518dff1f22d45'), 'Country': 'Austria', 'Year': '2018', 'Total': '7.528656', 'Coal': '1.390778', 'Oil': '3.855559', 'Gas': '1.925170', 'Cement': '0.206623', 'Flaring': '0.014394', 'Other': '0.136131', 'ISO': 'AUT'}
# {'_id': ObjectId('64273cf6cfb518dff1f22d46'), 'Country': 'Austria', 'Year': '2019', 'Total': '7.650523', 'Coal': '1.464565', 'Oil': '3.838689', 'Gas': '2.003686', 'Cement': '0.199385', 'Flaring': '0.013317', 'Other': '0.130881', 'ISO': 'AUT'}
# {'_id': ObjectId('64273cf6cfb518dff1f22d47'), 'Country': 'Austria', 'Year': '2020', 'Total': '6.964414', 'Coal': '1.279033', 'Oil': '3.447875', 'Gas': '1.894629', 'Cement': '0.204442', 'Flaring': '0.012265', 'Other': '0.126170', 'ISO': 'AUT'}
# {'_id': ObjectId('64273cf6cfb518dff1f22d48'), 'Country': 'Austria', 'Year': '2021', 'Total': '7.243330', 'Coal': '1.375153', 'Oil': '3.526375', 'Gas': '1.999475', 'Cement': '0.204114', 'Flaring': '0.012245', 'Other': '0.125968', 'ISO': 'AUT'}
# {'_id': ObjectId('64273cf6cfb518dff1f22e54'), 'Country': 'Azerbaijan', 'Year': '2017', 'Total': '3.436113', 'Coal': '0.000364', 'Oil': '1.240910', 'Gas': '2.074367', 'Cement': '0.092232', 'Flaring': '0.028240', 'Other': '', 'ISO': 'AZE'}
# {'_id': ObjectId('64273cf6cfb518dff1f22e55'), 'Country': 'Azerbaijan', 'Year': '2018', 'Total': '3.405638', 'Coal': '0.000361', 'Oil': '1.165693', 'Gas': '2.096442', 'Cement': '0.106669', 'Flaring': '0.036474', 'Other': '', 'ISO': 'AZE'}
# {'_id': ObjectId('64273cf6cfb518dff1f22e56'), 'Country': 'Azerbaijan', 'Year': '2019', 'Total': '3.687951', 'Coal': '0.000358', 'Oil': '1.182227', 'Gas': '2.357292', 'Cement': '0.107153', 'Flaring': '0.040921', 'Other': '', 'ISO': 'AZE'}
# {'_id': ObjectId('64273cf6cfb518dff1f22e57'), 'Country': 'Azerbaijan', 'Year': '2020', 'Total': '3.646883', 'Coal': '0.000357', 'Oil': '1.054768', 'Gas': '2.460449', 'Cement': '0.106609', 'Flaring': '0.024701', 'Other': '', 'ISO': 'AZE'}
# {'_id': ObjectId('64273cf6cfb518dff1f22e58'), 'Country': 'Azerbaijan', 'Year': '2021', 'Total': '3.732457', 'Coal': '0.000355', 'Oil': '1.077332', 'Gas': '2.523936', 'Cement': '0.106319', 'Flaring': '0.024515', 'Other': '', 'ISO': 'AZE'}
# {'_id': ObjectId('64273cf6cfb518dff1f22f64'), 'Country': 'Bahamas', 'Year': '2017', 'Total': '5.252388', 'Coal': '0.009199', 'Oil': '5.243190', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BHS'}
# {'_id': ObjectId('64273cf6cfb518dff1f22f65'), 'Country': 'Bahamas', 'Year': '2018', 'Total': '6.718904', 'Coal': '0.009117', 'Oil': '6.709788', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BHS'}
# {'_id': ObjectId('64273cf6cfb518dff1f22f66'), 'Country': 'Bahamas', 'Year': '2019', 'Total': '6.267320', 'Coal': '0.009057', 'Oil': '6.258263', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BHS'}
# {'_id': ObjectId('64273cf6cfb518dff1f22f67'), 'Country': 'Bahamas', 'Year': '2020', 'Total': '5.330450', 'Coal': '0.012293', 'Oil': '5.318157', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BHS'}
# {'_id': ObjectId('64273cf6cfb518dff1f22f68'), 'Country': 'Bahamas', 'Year': '2021', 'Total': '5.850522', 'Coal': '0.012448', 'Oil': '5.838075', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BHS'}
# {'_id': ObjectId('64273cf6cfb518dff1f23074'), 'Country': 'Bahrain', 'Year': '2017', 'Total': '22.538732', 'Coal': '0', 'Oil': '2.799243', 'Gas': '19.212413', 'Cement': '0.357213', 'Flaring': '0.169865', 'Other': '', 'ISO': 'BHR'}
# {'_id': ObjectId('64273cf6cfb518dff1f23075'), 'Country': 'Bahrain', 'Year': '2018', 'Total': '22.044145', 'Coal': '0', 'Oil': '2.473312', 'Gas': '19.099192', 'Cement': '0.375716', 'Flaring': '0.095925', 'Other': '', 'ISO': 'BHR'}
# {'_id': ObjectId('64273cf6cfb518dff1f23076'), 'Country': 'Bahrain', 'Year': '2019', 'Total': '25.307178', 'Coal': '0', 'Oil': '2.508568', 'Gas': '22.172503', 'Cement': '0.411394', 'Flaring': '0.214713', 'Other': '', 'ISO': 'BHR'}
# {'_id': ObjectId('64273cf6cfb518dff1f23077'), 'Country': 'Bahrain', 'Year': '2020', 'Total': '25.450788', 'Coal': '0', 'Oil': '2.344683', 'Gas': '22.389554', 'Cement': '0.416049', 'Flaring': '0.300501', 'Other': '', 'ISO': 'BHR'}
# {'_id': ObjectId('64273cf6cfb518dff1f23078'), 'Country': 'Bahrain', 'Year': '2021', 'Total': '26.663720', 'Coal': '0', 'Oil': '2.426313', 'Gas': '23.642933', 'Cement': '0.420088', 'Flaring': '0.174386', 'Other': '', 'ISO': 'BHR'}
# {'_id': ObjectId('64273cf6cfb518dff1f23184'), 'Country': 'Bangladesh', 'Year': '2017', 'Total': '0.498975', 'Coal': '0.044203', 'Oil': '0.115626', 'Gas': '0.331684', 'Cement': '0.007386', 'Flaring': '0.000075', 'Other': '', 'ISO': 'BGD'}
# {'_id': ObjectId('64273cf6cfb518dff1f23185'), 'Country': 'Bangladesh', 'Year': '2018', 'Total': '0.503982', 'Coal': '0.049964', 'Oil': '0.119650', 'Gas': '0.326112', 'Cement': '0.008139', 'Flaring': '0.000116', 'Other': '', 'ISO': 'BGD'}
# {'_id': ObjectId('64273cf6cfb518dff1f23186'), 'Country': 'Bangladesh', 'Year': '2019', 'Total': '0.553767', 'Coal': '0.090647', 'Oil': '0.101383', 'Gas': '0.352671', 'Cement': '0.008905', 'Flaring': '0.000161', 'Other': '', 'ISO': 'BGD'}
# {'_id': ObjectId('64273cf6cfb518dff1f23187'), 'Country': 'Bangladesh', 'Year': '2020', 'Total': '0.542497', 'Coal': '0.101231', 'Oil': '0.095110', 'Gas': '0.337185', 'Cement': '0.008804', 'Flaring': '0.000167', 'Other': '', 'ISO': 'BGD'}
# {'_id': ObjectId('64273cf6cfb518dff1f23188'), 'Country': 'Bangladesh', 'Year': '2021', 'Total': '0.550177', 'Coal': '0.087702', 'Oil': '0.106622', 'Gas': '0.346862', 'Cement': '0.008703', 'Flaring': '0.000288', 'Other': '', 'ISO': 'BGD'}
# {'_id': ObjectId('64273cf6cfb518dff1f23294'), 'Country': 'Barbados', 'Year': '2017', 'Total': '4.321146', 'Coal': '0', 'Oil': '3.819032', 'Gas': '0.157486', 'Cement': '0.252761', 'Flaring': '0.091867', 'Other': '', 'ISO': 'BRB'}
# {'_id': ObjectId('64273cf6cfb518dff1f23295'), 'Country': 'Barbados', 'Year': '2018', 'Total': '4.601008', 'Coal': '0', 'Oil': '4.085938', 'Gas': '0.197071', 'Cement': '0.252309', 'Flaring': '0.065690', 'Other': '', 'ISO': 'BRB'}
# {'_id': ObjectId('64273cf6cfb518dff1f23296'), 'Country': 'Barbados', 'Year': '2019', 'Total': '4.201212', 'Coal': '0', 'Oil': '3.713955', 'Gas': '0.170005', 'Cement': '0.251866', 'Flaring': '0.065387', 'Other': '', 'ISO': 'BRB'}
# {'_id': ObjectId('64273cf6cfb518dff1f23297'), 'Country': 'Barbados', 'Year': '2020', 'Total': '3.639515', 'Coal': '0', 'Oil': '3.165187', 'Gas': '0.157655', 'Cement': '0.251405', 'Flaring': '0.065267', 'Other': '', 'ISO': 'BRB'}
# {'_id': ObjectId('64273cf6cfb518dff1f23298'), 'Country': 'Barbados', 'Year': '2021', 'Total': '4.001781', 'Coal': '0', 'Oil': '3.480605', 'Gas': '0.205075', 'Cement': '0.250952', 'Flaring': '0.065149', 'Other': '', 'ISO': 'BRB'}
# {'_id': ObjectId('64273cf6cfb518dff1f233a4'), 'Country': 'Belarus', 'Year': '2017', 'Total': '6.104557', 'Coal': '0.399908', 'Oil': '1.786644', 'Gas': '3.569172', 'Cement': '0.229419', 'Flaring': '0.000629', 'Other': '0.118785', 'ISO': 'BLR'}
# {'_id': ObjectId('64273cf6cfb518dff1f233a5'), 'Country': 'Belarus', 'Year': '2018', 'Total': '6.404399', 'Coal': '0.408726', 'Oil': '1.874861', 'Gas': '3.790441', 'Cement': '0.223125', 'Flaring': '0.000648', 'Other': '0.106598', 'ISO': 'BLR'}
# {'_id': ObjectId('64273cf6cfb518dff1f233a6'), 'Country': 'Belarus', 'Year': '2019', 'Total': '6.413033', 'Coal': '0.423781', 'Oil': '1.864440', 'Gas': '3.786235', 'Cement': '0.235276', 'Flaring': '0.000655', 'Other': '0.102645', 'ISO': 'BLR'}
# {'_id': ObjectId('64273cf6cfb518dff1f233a7'), 'Country': 'Belarus', 'Year': '2020', 'Total': '6.081962', 'Coal': '0.392108', 'Oil': '1.858074', 'Gas': '3.491142', 'Cement': '0.238993', 'Flaring': '0.000647', 'Other': '0.100998', 'ISO': 'BLR'}
# {'_id': ObjectId('64273cf6cfb518dff1f233a8'), 'Country': 'Belarus', 'Year': '2021', 'Total': '6.222741', 'Coal': '0.342635', 'Oil': '1.773462', 'Gas': '3.764030', 'Cement': '0.240379', 'Flaring': '0.000651', 'Other': '0.101584', 'ISO': 'BLR'}
# {'_id': ObjectId('64273cf6cfb518dff1f234b4'), 'Country': 'Belgium', 'Year': '2017', 'Total': '8.707135', 'Coal': '1.168967', 'Oil': '4.069848', 'Gas': '3.077016', 'Cement': '0.201275', 'Flaring': '0.008691', 'Other': '0.181338', 'ISO': 'BEL'}
# {'_id': ObjectId('64273cf6cfb518dff1f234b5'), 'Country': 'Belgium', 'Year': '2018', 'Total': '8.723658', 'Coal': '1.167562', 'Oil': '3.992980', 'Gas': '3.153067', 'Cement': '0.221371', 'Flaring': '0.010590', 'Other': '0.178088', 'ISO': 'BEL'}
# {'_id': ObjectId('64273cf6cfb518dff1f234b6'), 'Country': 'Belgium', 'Year': '2019', 'Total': '8.638376', 'Coal': '1.146097', 'Oil': '3.930573', 'Gas': '3.144868', 'Cement': '0.244932', 'Flaring': '0.010087', 'Other': '0.161820', 'ISO': 'BEL'}
# {'_id': ObjectId('64273cf6cfb518dff1f234b7'), 'Country': 'Belgium', 'Year': '2020', 'Total': '7.816141', 'Coal': '0.921254', 'Oil': '3.416304', 'Gas': '3.101308', 'Cement': '0.227845', 'Flaring': '0.008775', 'Other': '0.140655', 'ISO': 'BEL'}
# {'_id': ObjectId('64273cf6cfb518dff1f234b8'), 'Country': 'Belgium', 'Year': '2021', 'Total': '8.243806', 'Coal': '0.948716', 'Oil': '3.838220', 'Gas': '3.081210', 'Cement': '0.226870', 'Flaring': '0.008737', 'Other': '0.140053', 'ISO': 'BEL'}
# {'_id': ObjectId('64273cf6cfb518dff1f235c4'), 'Country': 'Belize', 'Year': '2017', 'Total': '1.642817', 'Coal': '0', 'Oil': '1.633038', 'Gas': '0.009779', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BLZ'}
# {'_id': ObjectId('64273cf6cfb518dff1f235c5'), 'Country': 'Belize', 'Year': '2018', 'Total': '1.582344', 'Coal': '0', 'Oil': '1.572754', 'Gas': '0.009590', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BLZ'}
# {'_id': ObjectId('64273cf6cfb518dff1f235c6'), 'Country': 'Belize', 'Year': '2019', 'Total': '1.817428', 'Coal': '0', 'Oil': '1.817428', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BLZ'}
# {'_id': ObjectId('64273cf6cfb518dff1f235c7'), 'Country': 'Belize', 'Year': '2020', 'Total': '1.556447', 'Coal': '0', 'Oil': '1.552782', 'Gas': '0', 'Cement': '0', 'Flaring': '0.003666', 'Other': '', 'ISO': 'BLZ'}
# {'_id': ObjectId('64273cf6cfb518dff1f235c8'), 'Country': 'Belize', 'Year': '2021', 'Total': '1.723170', 'Coal': '0', 'Oil': '1.711186', 'Gas': '0', 'Cement': '0', 'Flaring': '0.011984', 'Other': '', 'ISO': 'BLZ'}
# {'_id': ObjectId('64273cf6cfb518dff1f236d4'), 'Country': 'Benin', 'Year': '2017', 'Total': '0.586728', 'Coal': '0.017386', 'Oil': '0.544662', 'Gas': '0.006322', 'Cement': '0.018358', 'Flaring': '0', 'Other': '', 'ISO': 'BEN'}
# {'_id': ObjectId('64273cf6cfb518dff1f236d5'), 'Country': 'Benin', 'Year': '2018', 'Total': '0.622619', 'Coal': '0', 'Oil': '0.586697', 'Gas': '0.003069', 'Cement': '0.032853', 'Flaring': '0', 'Other': '', 'ISO': 'BEN'}
# {'_id': ObjectId('64273cf6cfb518dff1f236d6'), 'Country': 'Benin', 'Year': '2019', 'Total': '0.581269', 'Coal': '0.022061', 'Oil': '0.519023', 'Gas': '0.008645', 'Cement': '0.031540', 'Flaring': '0', 'Other': '', 'ISO': 'BEN'}
# {'_id': ObjectId('64273cf6cfb518dff1f236d7'), 'Country': 'Benin', 'Year': '2020', 'Total': '0.574526', 'Coal': '0.019449', 'Oil': '0.515422', 'Gas': '0.008995', 'Cement': '0.030660', 'Flaring': '0', 'Other': '', 'ISO': 'BEN'}
# {'_id': ObjectId('64273cf6cfb518dff1f236d8'), 'Country': 'Benin', 'Year': '2021', 'Total': '0.596744', 'Coal': '0.021878', 'Oil': '0.535575', 'Gas': '0.009465', 'Cement': '0.029825', 'Flaring': '0', 'Other': '', 'ISO': 'BEN'}
# {'_id': ObjectId('64273cf6cfb518dff1f237e4'), 'Country': 'Bermuda', 'Year': '2017', 'Total': '9.959826', 'Coal': '0', 'Oil': '9.959826', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BMU'}
# {'_id': ObjectId('64273cf6cfb518dff1f237e5'), 'Country': 'Bermuda', 'Year': '2018', 'Total': '11.066178', 'Coal': '0', 'Oil': '11.066178', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BMU'}
# {'_id': ObjectId('64273cf6cfb518dff1f237e6'), 'Country': 'Bermuda', 'Year': '2019', 'Total': '9.129568', 'Coal': '0', 'Oil': '9.129568', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BMU'}
# {'_id': ObjectId('64273cf6cfb518dff1f237e7'), 'Country': 'Bermuda', 'Year': '2020', 'Total': '7.768184', 'Coal': '0', 'Oil': '7.768184', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BMU'}
# {'_id': ObjectId('64273cf6cfb518dff1f237e8'), 'Country': 'Bermuda', 'Year': '2021', 'Total': '8.537196', 'Coal': '0', 'Oil': '8.537196', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BMU'}
# {'_id': ObjectId('64273cf6cfb518dff1f238f4'), 'Country': 'Bhutan', 'Year': '2017', 'Total': '1.638922', 'Coal': '0.503962', 'Oil': '0.683256', 'Gas': '0', 'Cement': '0.451704', 'Flaring': '0', 'Other': '', 'ISO': 'BTN'}
# {'_id': ObjectId('64273cf6cfb518dff1f238f5'), 'Country': 'Bhutan', 'Year': '2018', 'Total': '1.770616', 'Coal': '0.556209', 'Oil': '0.743210', 'Gas': '0', 'Cement': '0.471197', 'Flaring': '0', 'Other': '', 'ISO': 'BTN'}
# {'_id': ObjectId('64273cf6cfb518dff1f238f6'), 'Country': 'Bhutan', 'Year': '2019', 'Total': '1.885524', 'Coal': '0.549033', 'Oil': '0.744775', 'Gas': '0', 'Cement': '0.591717', 'Flaring': '0', 'Other': '', 'ISO': 'BTN'}
# {'_id': ObjectId('64273cf6cfb518dff1f238f7'), 'Country': 'Bhutan', 'Year': '2020', 'Total': '1.941335', 'Coal': '0.572572', 'Oil': '0.780912', 'Gas': '0', 'Cement': '0.587851', 'Flaring': '0', 'Other': '', 'ISO': 'BTN'}
# {'_id': ObjectId('64273cf6cfb518dff1f238f8'), 'Country': 'Bhutan', 'Year': '2021', 'Total': '1.957702', 'Coal': '0.576234', 'Oil': '0.797382', 'Gas': '0', 'Cement': '0.584086', 'Flaring': '0', 'Other': '', 'ISO': 'BTN'}
# {'_id': ObjectId('64273cf6cfb518dff1f23a04'), 'Country': 'Bonaire, Saint Eustatius and Saba', 'Year': '2017', 'Total': '4.210457', 'Coal': '0', 'Oil': '4.210457', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BES'}
# {'_id': ObjectId('64273cf6cfb518dff1f23a05'), 'Country': 'Bonaire, Saint Eustatius and Saba', 'Year': '2018', 'Total': '3.961874', 'Coal': '0', 'Oil': '3.961874', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BES'}
# {'_id': ObjectId('64273cf6cfb518dff1f23a06'), 'Country': 'Bonaire, Saint Eustatius and Saba', 'Year': '2019', 'Total': '4.298788', 'Coal': '0', 'Oil': '4.298788', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BES'}
# {'_id': ObjectId('64273cf6cfb518dff1f23a07'), 'Country': 'Bonaire, Saint Eustatius and Saba', 'Year': '2020', 'Total': '3.588496', 'Coal': '0', 'Oil': '3.588496', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BES'}
# {'_id': ObjectId('64273cf6cfb518dff1f23a08'), 'Country': 'Bonaire, Saint Eustatius and Saba', 'Year': '2021', 'Total': '3.871365', 'Coal': '0', 'Oil': '3.871365', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BES'}
# {'_id': ObjectId('64273cf6cfb518dff1f23b14'), 'Country': 'Bosnia and Herzegovina', 'Year': '2017', 'Total': '6.440698', 'Coal': '4.784465', 'Oil': '1.421919', 'Gas': '0.133138', 'Cement': '0.101175', 'Flaring': '0', 'Other': '', 'ISO': 'BIH'}
# {'_id': ObjectId('64273cf6cfb518dff1f23b15'), 'Country': 'Bosnia and Herzegovina', 'Year': '2018', 'Total': '6.492411', 'Coal': '4.882366', 'Oil': '1.364476', 'Gas': '0.133645', 'Cement': '0.111924', 'Flaring': '0', 'Other': '', 'ISO': 'BIH'}
# {'_id': ObjectId('64273cf6cfb518dff1f23b16'), 'Country': 'Bosnia and Herzegovina', 'Year': '2019', 'Total': '6.192254', 'Coal': '4.562677', 'Oil': '1.393334', 'Gas': '0.127559', 'Cement': '0.108685', 'Flaring': '0', 'Other': '', 'ISO': 'BIH'}
# {'_id': ObjectId('64273cf6cfb518dff1f23b17'), 'Country': 'Bosnia and Herzegovina', 'Year': '2020', 'Total': '6.308132', 'Coal': '4.749921', 'Oil': '1.319667', 'Gas': '0.128474', 'Cement': '0.110070', 'Flaring': '0', 'Other': '', 'ISO': 'BIH'}
# {'_id': ObjectId('64273cf6cfb518dff1f23b18'), 'Country': 'Bosnia and Herzegovina', 'Year': '2021', 'Total': '4.147523', 'Coal': '2.535815', 'Oil': '1.350757', 'Gas': '0.149283', 'Cement': '0.111667', 'Flaring': '0', 'Other': '', 'ISO': 'BIH'}
# {'_id': ObjectId('64273cf6cfb518dff1f23c24'), 'Country': 'Botswana', 'Year': '2017', 'Total': '2.946629', 'Coal': '1.771102', 'Oil': '1.173107', 'Gas': '0', 'Cement': '0.002420', 'Flaring': '0', 'Other': '', 'ISO': 'BWA'}
# {'_id': ObjectId('64273cf6cfb518dff1f23c25'), 'Country': 'Botswana', 'Year': '2018', 'Total': '3.061203', 'Coal': '1.886249', 'Oil': '1.174795', 'Gas': '0', 'Cement': '0.000158', 'Flaring': '0', 'Other': '', 'ISO': 'BWA'}
# {'_id': ObjectId('64273cf6cfb518dff1f23c26'), 'Country': 'Botswana', 'Year': '2019', 'Total': '2.713149', 'Coal': '1.544295', 'Oil': '1.168854', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BWA'}
# {'_id': ObjectId('64273cf6cfb518dff1f23c27'), 'Country': 'Botswana', 'Year': '2020', 'Total': '2.457817', 'Coal': '1.361848', 'Oil': '1.095969', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BWA'}
# {'_id': ObjectId('64273cf6cfb518dff1f23c28'), 'Country': 'Botswana', 'Year': '2021', 'Total': '2.511150', 'Coal': '1.411529', 'Oil': '1.099621', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'BWA'}
# {'_id': ObjectId('64273cf6cfb518dff1f23d34'), 'Country': 'Brazil', 'Year': '2017', 'Total': '2.385616', 'Coal': '0.322879', 'Oil': '1.517591', 'Gas': '0.339022', 'Cement': '0.091512', 'Flaring': '0.083955', 'Other': '0.030656', 'ISO': 'BRA'}
# {'_id': ObjectId('64273cf6cfb518dff1f23d35'), 'Country': 'Brazil', 'Year': '2018', 'Total': '2.270114', 'Coal': '0.313279', 'Oil': '1.430318', 'Gas': '0.320779', 'Cement': '0.092033', 'Flaring': '0.083291', 'Other': '0.030414', 'ISO': 'BRA'}
# {'_id': ObjectId('64273cf6cfb518dff1f23d36'), 'Country': 'Brazil', 'Year': '2019', 'Total': '2.243357', 'Coal': '0.292223', 'Oil': '1.427564', 'Gas': '0.316935', 'Cement': '0.093799', 'Flaring': '0.082655', 'Other': '0.030182', 'ISO': 'BRA'}
# {'_id': ObjectId('64273cf6cfb518dff1f23d37'), 'Country': 'Brazil', 'Year': '2020', 'Total': '2.074642', 'Coal': '0.263798', 'Oil': '1.318454', 'Gas': '0.276863', 'Cement': '0.103438', 'Flaring': '0.082107', 'Other': '0.029982', 'ISO': 'BRA'}
# {'_id': ObjectId('64273cf6cfb518dff1f23d38'), 'Country': 'Brazil', 'Year': '2021', 'Total': '2.281014', 'Coal': '0.318346', 'Oil': '1.385677', 'Gas': '0.354480', 'Cement': '0.111013', 'Flaring': '0.081675', 'Other': '0.029824', 'ISO': 'BRA'}
# {'_id': ObjectId('64273cf6cfb518dff1f23e44'), 'Country': 'British Virgin Islands', 'Year': '2017', 'Total': '5.606919', 'Coal': '0', 'Oil': '5.606919', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'VGB'}
# {'_id': ObjectId('64273cf6cfb518dff1f23e45'), 'Country': 'British Virgin Islands', 'Year': '2018', 'Total': '5.314521', 'Coal': '0', 'Oil': '5.314521', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'VGB'}
# {'_id': ObjectId('64273cf6cfb518dff1f23e46'), 'Country': 'British Virgin Islands', 'Year': '2019', 'Total': '5.506174', 'Coal': '0', 'Oil': '5.506174', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'VGB'}
# {'_id': ObjectId('64273cf6cfb518dff1f23e47'), 'Country': 'British Virgin Islands', 'Year': '2020', 'Total': '4.655555', 'Coal': '0', 'Oil': '4.655555', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'VGB'}
# {'_id': ObjectId('64273cf6cfb518dff1f23e48'), 'Country': 'British Virgin Islands', 'Year': '2021', 'Total': '5.093802', 'Coal': '0', 'Oil': '5.093802', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'VGB'}
# {'_id': ObjectId('64273cf6cfb518dff1f23f54'), 'Country': 'Brunei Darussalam', 'Year': '2017', 'Total': '21.635841', 'Coal': '0', 'Oil': '4.479134', 'Gas': '15.855795', 'Cement': '0', 'Flaring': '1.300912', 'Other': '', 'ISO': 'BRN'}
# {'_id': ObjectId('64273cf6cfb518dff1f23f55'), 'Country': 'Brunei Darussalam', 'Year': '2018', 'Total': '21.517344', 'Coal': '0', 'Oil': '4.388911', 'Gas': '16.179891', 'Cement': '0', 'Flaring': '0.948541', 'Other': '', 'ISO': 'BRN'}
# {'_id': ObjectId('64273cf6cfb518dff1f23f56'), 'Country': 'Brunei Darussalam', 'Year': '2019', 'Total': '23.941461', 'Coal': '0.828074', 'Oil': '8.163635', 'Gas': '13.633940', 'Cement': '0', 'Flaring': '1.315813', 'Other': '', 'ISO': 'BRN'}
# {'_id': ObjectId('64273cf6cfb518dff1f23f57'), 'Country': 'Brunei Darussalam', 'Year': '2020', 'Total': '23.890806', 'Coal': '0.862020', 'Oil': '8.544315', 'Gas': '13.837468', 'Cement': '0', 'Flaring': '0.647003', 'Other': '', 'ISO': 'BRN'}
# {'_id': ObjectId('64273cf6cfb518dff1f23f58'), 'Country': 'Brunei Darussalam', 'Year': '2021', 'Total': '23.532003', 'Coal': '0.865973', 'Oil': '8.708841', 'Gas': '13.046933', 'Cement': '0', 'Flaring': '0.910255', 'Other': '', 'ISO': 'BRN'}
# {'_id': ObjectId('64273cf6cfb518dff1f24064'), 'Country': 'Bulgaria', 'Year': '2017', 'Total': '6.623075', 'Coal': '3.591250', 'Oil': '1.717848', 'Gas': '0.840747', 'Cement': '0.172547', 'Flaring': '0.122168', 'Other': '0.178516', 'ISO': 'BGR'}
# {'_id': ObjectId('64273cf6cfb518dff1f24065'), 'Country': 'Bulgaria', 'Year': '2018', 'Total': '6.128063', 'Coal': '3.103544', 'Oil': '1.764093', 'Gas': '0.812233', 'Cement': '0.171902', 'Flaring': '0.099959', 'Other': '0.176330', 'ISO': 'BGR'}
# {'_id': ObjectId('64273cf6cfb518dff1f24066'), 'Country': 'Bulgaria', 'Year': '2019', 'Total': '5.991574', 'Coal': '2.944635', 'Oil': '1.856303', 'Gas': '0.743668', 'Cement': '0.159815', 'Flaring': '0.117263', 'Other': '0.169888', 'ISO': 'BGR'}
# {'_id': ObjectId('64273cf6cfb518dff1f24067'), 'Country': 'Bulgaria', 'Year': '2020', 'Total': '5.296774', 'Coal': '2.378158', 'Oil': '1.739669', 'Gas': '0.768244', 'Cement': '0.152726', 'Flaring': '0.098038', 'Other': '0.159939', 'ISO': 'BGR'}
# {'_id': ObjectId('64273cf6cfb518dff1f24068'), 'Country': 'Bulgaria', 'Year': '2021', 'Total': '6.180805', 'Coal': '3.028459', 'Oil': '1.855755', 'Gas': '0.880323', 'Cement': '0.154796', 'Flaring': '0.099366', 'Other': '0.162107', 'ISO': 'BGR'}
# {'_id': ObjectId('64273cf6cfb518dff1f24174'), 'Country': 'Burkina Faso', 'Year': '2017', 'Total': '0.227822', 'Coal': '0', 'Oil': '0.192659', 'Gas': '0', 'Cement': '0.035163', 'Flaring': '0', 'Other': '', 'ISO': 'BFA'}
# {'_id': ObjectId('64273cf6cfb518dff1f24175'), 'Country': 'Burkina Faso', 'Year': '2018', 'Total': '0.242629', 'Coal': '0', 'Oil': '0.205006', 'Gas': '0', 'Cement': '0.037623', 'Flaring': '0', 'Other': '', 'ISO': 'BFA'}
# {'_id': ObjectId('64273cf6cfb518dff1f24176'), 'Country': 'Burkina Faso', 'Year': '2019', 'Total': '0.252788', 'Coal': '0', 'Oil': '0.212100', 'Gas': '0', 'Cement': '0.040688', 'Flaring': '0', 'Other': '', 'ISO': 'BFA'}
# {'_id': ObjectId('64273cf6cfb518dff1f24177'), 'Country': 'Burkina Faso', 'Year': '2020', 'Total': '0.250387', 'Coal': '0', 'Oil': '0.210778', 'Gas': '0', 'Cement': '0.039609', 'Flaring': '0', 'Other': '', 'ISO': 'BFA'}
# {'_id': ObjectId('64273cf6cfb518dff1f24178'), 'Country': 'Burkina Faso', 'Year': '2021', 'Total': '0.257832', 'Coal': '0', 'Oil': '0.219259', 'Gas': '0', 'Cement': '0.038573', 'Flaring': '0', 'Other': '', 'ISO': 'BFA'}
# {'_id': ObjectId('64273cf6cfb518dff1f24284'), 'Country': 'Burundi', 'Year': '2017', 'Total': '0.047545', 'Coal': '0.001971', 'Oil': '0.044012', 'Gas': '0', 'Cement': '0.001563', 'Flaring': '0', 'Other': '', 'ISO': 'BDI'}
# {'_id': ObjectId('64273cf6cfb518dff1f24285'), 'Country': 'Burundi', 'Year': '2018', 'Total': '0.059497', 'Coal': '0.001585', 'Oil': '0.054540', 'Gas': '0', 'Cement': '0.003371', 'Flaring': '0', 'Other': '', 'ISO': 'BDI'}
# {'_id': ObjectId('64273cf6cfb518dff1f24286'), 'Country': 'Burundi', 'Year': '2019', 'Total': '0.060455', 'Coal': '0.004011', 'Oil': '0.053997', 'Gas': '0', 'Cement': '0.002447', 'Flaring': '0', 'Other': '', 'ISO': 'BDI'}
# {'_id': ObjectId('64273cf6cfb518dff1f24287'), 'Country': 'Burundi', 'Year': '2020', 'Total': '0.053774', 'Coal': '0.003803', 'Oil': '0.047592', 'Gas': '0', 'Cement': '0.002378', 'Flaring': '0', 'Other': '', 'ISO': 'BDI'}
# {'_id': ObjectId('64273cf6cfb518dff1f24288'), 'Country': 'Burundi', 'Year': '2021', 'Total': '0.055206', 'Coal': '0.003981', 'Oil': '0.048910', 'Gas': '0', 'Cement': '0.002315', 'Flaring': '0', 'Other': '', 'ISO': 'BDI'}
# {'_id': ObjectId('64273cf6cfb518dff1f24394'), 'Country': 'Cambodia', 'Year': '2017', 'Total': '0.789911', 'Coal': '0.228209', 'Oil': '0.416377', 'Gas': '0', 'Cement': '0.145325', 'Flaring': '0', 'Other': '', 'ISO': 'KHM'}
# {'_id': ObjectId('64273cf6cfb518dff1f24395'), 'Country': 'Cambodia', 'Year': '2018', 'Total': '0.897845', 'Coal': '0.239614', 'Oil': '0.451334', 'Gas': '0', 'Cement': '0.206897', 'Flaring': '0', 'Other': '', 'ISO': 'KHM'}
# {'_id': ObjectId('64273cf6cfb518dff1f24396'), 'Country': 'Cambodia', 'Year': '2019', 'Total': '1.112100', 'Coal': '0.272634', 'Oil': '0.510906', 'Gas': '0', 'Cement': '0.328560', 'Flaring': '0', 'Other': '', 'ISO': 'KHM'}
# {'_id': ObjectId('64273cf6cfb518dff1f24397'), 'Country': 'Cambodia', 'Year': '2020', 'Total': '1.140663', 'Coal': '0.282892', 'Oil': '0.533000', 'Gas': '0', 'Cement': '0.324771', 'Flaring': '0', 'Other': '', 'ISO': 'KHM'}
# {'_id': ObjectId('64273cf6cfb518dff1f24398'), 'Country': 'Cambodia', 'Year': '2021', 'Total': '1.147060', 'Coal': '0.283217', 'Oil': '0.541405', 'Gas': '0', 'Cement': '0.321008', 'Flaring': '0.001429', 'Other': '', 'ISO': 'KHM'}
# {'_id': ObjectId('64273cf6cfb518dff1f244a4'), 'Country': 'Canada', 'Year': '2017', 'Total': '15.635476', 'Coal': '1.988497', 'Oil': '7.123722', 'Gas': '5.870196', 'Cement': '0.186770', 'Flaring': '0.405826', 'Other': '0.060465', 'ISO': 'CAN'}
# {'_id': ObjectId('64273cf6cfb518dff1f244a5'), 'Country': 'Canada', 'Year': '2018', 'Total': '15.778726', 'Coal': '1.641559', 'Oil': '7.208382', 'Gas': '6.263775', 'Cement': '0.186708', 'Flaring': '0.419857', 'Other': '0.058445', 'ISO': 'CAN'}
# {'_id': ObjectId('64273cf6cfb518dff1f244a6'), 'Country': 'Canada', 'Year': '2019', 'Total': '15.582994', 'Coal': '1.554416', 'Oil': '7.177703', 'Gas': '6.181943', 'Cement': '0.189890', 'Flaring': '0.421818', 'Other': '0.057222', 'ISO': 'CAN'}
# {'_id': ObjectId('64273cf6cfb518dff1f244a7'), 'Country': 'Canada', 'Year': '2020', 'Total': '14.116709', 'Coal': '1.267792', 'Oil': '6.291544', 'Gas': '5.904646', 'Cement': '0.174847', 'Flaring': '0.423793', 'Other': '0.054087', 'ISO': 'CAN'}
# {'_id': ObjectId('64273cf6cfb518dff1f244a8'), 'Country': 'Canada', 'Year': '2021', 'Total': '14.300468', 'Coal': '1.149576', 'Oil': '6.333628', 'Gas': '6.169093', 'Cement': '0.173626', 'Flaring': '0.420835', 'Other': '0.053709', 'ISO': 'CAN'}
# {'_id': ObjectId('64273cf6cfb518dff1f245b4'), 'Country': 'Cape Verde', 'Year': '2017', 'Total': '1.024706', 'Coal': '0', 'Oil': '1.024706', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'CPV'}
# {'_id': ObjectId('64273cf6cfb518dff1f245b5'), 'Country': 'Cape Verde', 'Year': '2018', 'Total': '1.019912', 'Coal': '0', 'Oil': '1.019912', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'CPV'}
# {'_id': ObjectId('64273cf6cfb518dff1f245b6'), 'Country': 'Cape Verde', 'Year': '2019', 'Total': '1.060409', 'Coal': '0', 'Oil': '1.060409', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'CPV'}
# {'_id': ObjectId('64273cf6cfb518dff1f245b7'), 'Country': 'Cape Verde', 'Year': '2020', 'Total': '1.072840', 'Coal': '0', 'Oil': '1.072840', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'CPV'}
# {'_id': ObjectId('64273cf6cfb518dff1f245b8'), 'Country': 'Cape Verde', 'Year': '2021', 'Total': '1.135678', 'Coal': '0', 'Oil': '1.135678', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'CPV'}
# {'_id': ObjectId('64273cf6cfb518dff1f246c4'), 'Country': 'Central African Republic', 'Year': '2017', 'Total': '0.043263', 'Coal': '0', 'Oil': '0.043263', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'CAF'}
# {'_id': ObjectId('64273cf6cfb518dff1f246c5'), 'Country': 'Central African Republic', 'Year': '2018', 'Total': '0.043150', 'Coal': '0', 'Oil': '0.043150', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'CAF'}
# {'_id': ObjectId('64273cf6cfb518dff1f246c6'), 'Country': 'Central African Republic', 'Year': '2019', 'Total': '0.043608', 'Coal': '0', 'Oil': '0.043608', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'CAF'}
# {'_id': ObjectId('64273cf6cfb518dff1f246c7'), 'Country': 'Central African Republic', 'Year': '2020', 'Total': '0.040097', 'Coal': '0', 'Oil': '0.040097', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'CAF'}
# {'_id': ObjectId('64273cf6cfb518dff1f246c8'), 'Country': 'Central African Republic', 'Year': '2021', 'Total': '0.041651', 'Coal': '0', 'Oil': '0.041651', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'CAF'}
# {'_id': ObjectId('64273cf6cfb518dff1f247d4'), 'Country': 'Chad', 'Year': '2017', 'Total': '0.131118', 'Coal': '0', 'Oil': '0.093022', 'Gas': '0', 'Cement': '0.008990', 'Flaring': '0.029106', 'Other': '', 'ISO': 'TCD'}
# {'_id': ObjectId('64273cf6cfb518dff1f247d5'), 'Country': 'Chad', 'Year': '2018', 'Total': '0.128603', 'Coal': '0', 'Oil': '0.093219', 'Gas': '0', 'Cement': '0.009933', 'Flaring': '0.025451', 'Other': '', 'ISO': 'TCD'}
# {'_id': ObjectId('64273cf6cfb518dff1f247d6'), 'Country': 'Chad', 'Year': '2019', 'Total': '0.119197', 'Coal': '0', 'Oil': '0.089289', 'Gas': '0', 'Cement': '0.010092', 'Flaring': '0.019817', 'Other': '', 'ISO': 'TCD'}
# {'_id': ObjectId('64273cf6cfb518dff1f247d7'), 'Country': 'Chad', 'Year': '2020', 'Total': '0.108275', 'Coal': '0', 'Oil': '0.081588', 'Gas': '0', 'Cement': '0.009778', 'Flaring': '0.016908', 'Other': '', 'ISO': 'TCD'}
# {'_id': ObjectId('64273cf6cfb518dff1f247d8'), 'Country': 'Chad', 'Year': '2021', 'Total': '0.112919', 'Coal': '0', 'Oil': '0.083864', 'Gas': '0', 'Cement': '0.009473', 'Flaring': '0.019582', 'Other': '', 'ISO': 'TCD'}
# {'_id': ObjectId('64273cf6cfb518dff1f248e4'), 'Country': 'Chile', 'Year': '2017', 'Total': '4.577088', 'Coal': '1.510130', 'Oil': '2.475329', 'Gas': '0.541341', 'Cement': '0.047140', 'Flaring': '0.003147', 'Other': '', 'ISO': 'CHL'}
# {'_id': ObjectId('64273cf6cfb518dff1f248e5'), 'Country': 'Chile', 'Year': '2018', 'Total': '4.516692', 'Coal': '1.446348', 'Oil': '2.490063', 'Gas': '0.533711', 'Cement': '0.041826', 'Flaring': '0.004745', 'Other': '', 'ISO': 'CHL'}
# {'_id': ObjectId('64273cf6cfb518dff1f248e6'), 'Country': 'Chile', 'Year': '2019', 'Total': '4.830064', 'Coal': '1.629087', 'Oil': '2.522247', 'Gas': '0.632967', 'Cement': '0.043348', 'Flaring': '0.002414', 'Other': '', 'ISO': 'CHL'}
# {'_id': ObjectId('64273cf6cfb518dff1f248e7'), 'Country': 'Chile', 'Year': '2020', 'Total': '4.343649', 'Coal': '1.349790', 'Oil': '2.351882', 'Gas': '0.597774', 'Cement': '0.042762', 'Flaring': '0.001442', 'Other': '', 'ISO': 'CHL'}
# {'_id': ObjectId('64273cf6cfb518dff1f248e8'), 'Country': 'Chile', 'Year': '2021', 'Total': '4.383426', 'Coal': '1.343286', 'Oil': '2.401832', 'Gas': '0.595372', 'Cement': '0.042339', 'Flaring': '0.000596', 'Other': '', 'ISO': 'CHL'}
# {'_id': ObjectId('64273cf6cfb518dff1f249f4'), 'Country': 'China', 'Year': '2017', 'Total': '7.098687', 'Coal': '5.079373', 'Oil': '1.014402', 'Gas': '0.344868', 'Cement': '0.537615', 'Flaring': '0.002074', 'Other': '0.120355', 'ISO': 'CHN'}
# {'_id': ObjectId('64273cf6cfb518dff1f249f5'), 'Country': 'China', 'Year': '2018', 'Total': '7.306542', 'Coal': '5.163049', 'Oil': '1.058857', 'Gas': '0.406027', 'Cement': '0.555191', 'Flaring': '0.002365', 'Other': '0.121052', 'ISO': 'CHN'}
# {'_id': ObjectId('64273cf6cfb518dff1f249f6'), 'Country': 'China', 'Year': '2019', 'Total': '7.554165', 'Coal': '5.305119', 'Oil': '1.096960', 'Gas': '0.443201', 'Cement': '0.581544', 'Flaring': '0.002677', 'Other': '0.124665', 'ISO': 'CHN'}
# {'_id': ObjectId('64273cf6cfb518dff1f249f7'), 'Country': 'China', 'Year': '2020', 'Total': '7.688950', 'Coal': '5.337608', 'Oil': '1.142320', 'Gas': '0.482747', 'Cement': '0.602298', 'Flaring': '0.003592', 'Other': '0.120384', 'ISO': 'CHN'}
# {'_id': ObjectId('64273cf6cfb518dff1f249f8'), 'Country': 'China', 'Year': '2021', 'Total': '8.045741', 'Coal': '5.579649', 'Oil': '1.201590', 'Gas': '0.542724', 'Cement': '0.598194', 'Flaring': '0.003280', 'Other': '0.120303', 'ISO': 'CHN'}
# {'_id': ObjectId('64273cf6cfb518dff1f24b04'), 'Country': 'Christmas Island', 'Year': '2017', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'CXR'}
# {'_id': ObjectId('64273cf6cfb518dff1f24b05'), 'Country': 'Christmas Island', 'Year': '2018', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'CXR'}
# {'_id': ObjectId('64273cf6cfb518dff1f24b06'), 'Country': 'Christmas Island', 'Year': '2019', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'CXR'}
# {'_id': ObjectId('64273cf6cfb518dff1f24b07'), 'Country': 'Christmas Island', 'Year': '2020', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'CXR'}
# {'_id': ObjectId('64273cf6cfb518dff1f24b08'), 'Country': 'Christmas Island', 'Year': '2021', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'CXR'}
# {'_id': ObjectId('64273cf6cfb518dff1f24c14'), 'Country': 'Colombia', 'Year': '2017', 'Total': '1.648084', 'Coal': '0.303730', 'Oil': '0.750080', 'Gas': '0.464672', 'Cement': '0.108227', 'Flaring': '0.021376', 'Other': '', 'ISO': 'COL'}
# {'_id': ObjectId('64273cf6cfb518dff1f24c15'), 'Country': 'Colombia', 'Year': '2018', 'Total': '1.672725', 'Coal': '0.278312', 'Oil': '0.789801', 'Gas': '0.475820', 'Cement': '0.107585', 'Flaring': '0.021207', 'Other': '', 'ISO': 'COL'}
# {'_id': ObjectId('64273cf6cfb518dff1f24c16'), 'Country': 'Colombia', 'Year': '2019', 'Total': '1.921561', 'Coal': '0.367137', 'Oil': '0.951753', 'Gas': '0.472357', 'Cement': '0.110321', 'Flaring': '0.019994', 'Other': '', 'ISO': 'COL'}
# {'_id': ObjectId('64273cf6cfb518dff1f24c17'), 'Country': 'Colombia', 'Year': '2020', 'Total': '1.679256', 'Coal': '0.303833', 'Oil': '0.787472', 'Gas': '0.474573', 'Cement': '0.098985', 'Flaring': '0.014393', 'Other': '', 'ISO': 'COL'}
# {'_id': ObjectId('64273cf6cfb518dff1f24c18'), 'Country': 'Colombia', 'Year': '2021', 'Total': '1.780076', 'Coal': '0.233234', 'Oil': '0.969493', 'Gas': '0.451441', 'Cement': '0.113956', 'Flaring': '0.011953', 'Other': '', 'ISO': 'COL'}
# {'_id': ObjectId('64273cf6cfb518dff1f24d24'), 'Country': 'Comoros', 'Year': '2017', 'Total': '0.351168', 'Coal': '0', 'Oil': '0.351168', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'COM'}
# {'_id': ObjectId('64273cf6cfb518dff1f24d25'), 'Country': 'Comoros', 'Year': '2018', 'Total': '0.377580', 'Coal': '0', 'Oil': '0.377580', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'COM'}
# ...
# {'_id': ObjectId('64273cf8cfb518dff1f30825'), 'Country': 'United Kingdom', 'Year': '2018', 'Total': '5.715981', 'Coal': '0.500960', 'Oil': '2.605439', 'Gas': '2.430799', 'Cement': '0.065689', 'Flaring': '0.067382', 'Other': '0.045712', 'ISO': 'GBR'}
# {'_id': ObjectId('64273cf8cfb518dff1f30826'), 'Country': 'United Kingdom', 'Year': '2019', 'Total': '5.462124', 'Coal': '0.367074', 'Oil': '2.530682', 'Gas': '2.385805', 'Cement': '0.066616', 'Flaring': '0.064140', 'Other': '0.047808', 'ISO': 'GBR'}
# {'_id': ObjectId('64273cf8cfb518dff1f30827'), 'Country': 'United Kingdom', 'Year': '2020', 'Total': '4.865281', 'Coal': '0.340137', 'Oil': '2.147063', 'Gas': '2.228173', 'Cement': '0.058153', 'Flaring': '0.051337', 'Other': '0.040419', 'ISO': 'GBR'}
# {'_id': ObjectId('64273cf8cfb518dff1f30828'), 'Country': 'United Kingdom', 'Year': '2021', 'Total': '5.154100', 'Coal': '0.352101', 'Oil': '2.290553', 'Gas': '2.361200', 'Cement': '0.057961', 'Flaring': '0.051632', 'Other': '0.040652', 'ISO': 'GBR'}
# {'_id': ObjectId('64273cf8cfb518dff1f30934'), 'Country': 'Tanzania', 'Year': '2017', 'Total': '0.202659', 'Coal': '0.026568', 'Oil': '0.120794', 'Gas': '0.026373', 'Cement': '0.028924', 'Flaring': '0', 'Other': '', 'ISO': 'TZA'}
# {'_id': ObjectId('64273cf8cfb518dff1f30935'), 'Country': 'Tanzania', 'Year': '2018', 'Total': '0.202910', 'Coal': '0.028690', 'Oil': '0.119614', 'Gas': '0.024528', 'Cement': '0.030077', 'Flaring': '0', 'Other': '', 'ISO': 'TZA'}
# {'_id': ObjectId('64273cf8cfb518dff1f30936'), 'Country': 'Tanzania', 'Year': '2019', 'Total': '0.217854', 'Coal': '0.031577', 'Oil': '0.112847', 'Gas': '0.031271', 'Cement': '0.042158', 'Flaring': '0', 'Other': '', 'ISO': 'TZA'}
# {'_id': ObjectId('64273cf8cfb518dff1f30937'), 'Country': 'Tanzania', 'Year': '2020', 'Total': '0.199243', 'Coal': '0.029898', 'Oil': '0.099316', 'Gas': '0.029121', 'Cement': '0.040907', 'Flaring': '0', 'Other': '', 'ISO': 'TZA'}
# {'_id': ObjectId('64273cf8cfb518dff1f30938'), 'Country': 'Tanzania', 'Year': '2021', 'Total': '0.205366', 'Coal': '0.031188', 'Oil': '0.101726', 'Gas': '0.032757', 'Cement': '0.039695', 'Flaring': '0', 'Other': '', 'ISO': 'TZA'}
# {'_id': ObjectId('64273cf8cfb518dff1f30a44'), 'Country': 'USA', 'Year': '2017', 'Total': '15.800777', 'Coal': '3.967600', 'Oil': '7.018608', 'Gas': '4.428231', 'Cement': '0.122270', 'Flaring': '0.179645', 'Other': '0.084423', 'ISO': 'USA'}
# {'_id': ObjectId('64273cf8cfb518dff1f30a45'), 'Country': 'USA', 'Year': '2018', 'Total': '16.187923', 'Coal': '3.782144', 'Oil': '7.121344', 'Gas': '4.873608', 'Cement': '0.117332', 'Flaring': '0.219145', 'Other': '0.074349', 'ISO': 'USA'}
# {'_id': ObjectId('64273cf8cfb518dff1f30a46'), 'Country': 'USA', 'Year': '2019', 'Total': '15.730884', 'Coal': '3.202695', 'Oil': '7.055616', 'Gas': '5.007181', 'Cement': '0.122326', 'Flaring': '0.264367', 'Other': '0.078699', 'ISO': 'USA'}
# {'_id': ObjectId('64273cf8cfb518dff1f30a47'), 'Country': 'USA', 'Year': '2020', 'Total': '14.037218', 'Coal': '2.616442', 'Oil': '6.100269', 'Gas': '4.922510', 'Cement': '0.121115', 'Flaring': '0.201476', 'Other': '0.075405', 'ISO': 'USA'}
# {'_id': ObjectId('64273cf8cfb518dff1f30a48'), 'Country': 'USA', 'Year': '2021', 'Total': '14.858668', 'Coal': '2.974205', 'Oil': '6.628469', 'Gas': '4.857715', 'Cement': '0.122265', 'Flaring': '0.200845', 'Other': '0.075169', 'ISO': 'USA'}
# {'_id': ObjectId('64273cf8cfb518dff1f30b54'), 'Country': 'Uruguay', 'Year': '2017', 'Total': '1.800764', 'Coal': '0.001071', 'Oil': '1.670224', 'Gas': '0.035332', 'Cement': '0.094137', 'Flaring': '0', 'Other': '', 'ISO': 'URY'}
# {'_id': ObjectId('64273cf8cfb518dff1f30b55'), 'Country': 'Uruguay', 'Year': '2018', 'Total': '1.917388', 'Coal': '0.001069', 'Oil': '1.789746', 'Gas': '0.033143', 'Cement': '0.093429', 'Flaring': '0', 'Other': '', 'ISO': 'URY'}
# {'_id': ObjectId('64273cf8cfb518dff1f30b56'), 'Country': 'Uruguay', 'Year': '2019', 'Total': '1.892990', 'Coal': '0.001069', 'Oil': '1.759035', 'Gas': '0.048119', 'Cement': '0.084766', 'Flaring': '0', 'Other': '', 'ISO': 'URY'}
# {'_id': ObjectId('64273cf8cfb518dff1f30b57'), 'Country': 'Uruguay', 'Year': '2020', 'Total': '1.836247', 'Coal': '0.000375', 'Oil': '1.711625', 'Gas': '0.039498', 'Cement': '0.084749', 'Flaring': '0', 'Other': '', 'ISO': 'URY'}
# {'_id': ObjectId('64273cf8cfb518dff1f30b58'), 'Country': 'Uruguay', 'Year': '2021', 'Total': '1.966539', 'Coal': '0.000552', 'Oil': '1.834908', 'Gas': '0.046259', 'Cement': '0.084819', 'Flaring': '0', 'Other': '', 'ISO': 'URY'}
# {'_id': ObjectId('64273cf8cfb518dff1f30c64'), 'Country': 'Uzbekistan', 'Year': '2017', 'Total': '3.409875', 'Coal': '0.209325', 'Oil': '0.347881', 'Gas': '2.687962', 'Cement': '0.114735', 'Flaring': '0.049972', 'Other': '', 'ISO': 'UZB'}
# {'_id': ObjectId('64273cf8cfb518dff1f30c65'), 'Country': 'Uzbekistan', 'Year': '2018', 'Total': '3.589080', 'Coal': '0.297640', 'Oil': '0.360420', 'Gas': '2.768868', 'Cement': '0.116368', 'Flaring': '0.045782', 'Other': '', 'ISO': 'UZB'}
# {'_id': ObjectId('64273cf8cfb518dff1f30c66'), 'Country': 'Uzbekistan', 'Year': '2019', 'Total': '3.602454', 'Coal': '0.251096', 'Oil': '0.372311', 'Gas': '2.801610', 'Cement': '0.141889', 'Flaring': '0.035547', 'Other': '', 'ISO': 'UZB'}
# {'_id': ObjectId('64273cf8cfb518dff1f30c67'), 'Country': 'Uzbekistan', 'Year': '2020', 'Total': '3.526737', 'Coal': '0.338472', 'Oil': '0.326481', 'Gas': '2.691333', 'Cement': '0.139563', 'Flaring': '0.030889', 'Other': '', 'ISO': 'UZB'}
# {'_id': ObjectId('64273cf8cfb518dff1f30c68'), 'Country': 'Uzbekistan', 'Year': '2021', 'Total': '3.568847', 'Coal': '0.237196', 'Oil': '0.346405', 'Gas': '2.822092', 'Cement': '0.137291', 'Flaring': '0.025863', 'Other': '', 'ISO': 'UZB'}
# {'_id': ObjectId('64273cf8cfb518dff1f30d74'), 'Country': 'Vanuatu', 'Year': '2017', 'Total': '0.479715', 'Coal': '0', 'Oil': '0.479715', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'VUT'}
# {'_id': ObjectId('64273cf8cfb518dff1f30d75'), 'Country': 'Vanuatu', 'Year': '2018', 'Total': '0.591568', 'Coal': '0', 'Oil': '0.591568', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'VUT'}
# {'_id': ObjectId('64273cf8cfb518dff1f30d76'), 'Country': 'Vanuatu', 'Year': '2019', 'Total': '0.529612', 'Coal': '0', 'Oil': '0.529612', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'VUT'}
# {'_id': ObjectId('64273cf8cfb518dff1f30d77'), 'Country': 'Vanuatu', 'Year': '2020', 'Total': '0.545904', 'Coal': '0', 'Oil': '0.545904', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'VUT'}
# {'_id': ObjectId('64273cf8cfb518dff1f30d78'), 'Country': 'Vanuatu', 'Year': '2021', 'Total': '0.547911', 'Coal': '0', 'Oil': '0.547911', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'VUT'}
# {'_id': ObjectId('64273cf8cfb518dff1f30e84'), 'Country': 'Venezuela', 'Year': '2017', 'Total': '4.593233', 'Coal': '0.010190', 'Oil': '2.518056', 'Gas': '1.564779', 'Cement': '0.069798', 'Flaring': '0.430411', 'Other': '', 'ISO': 'VEN'}
# {'_id': ObjectId('64273cf8cfb518dff1f30e85'), 'Country': 'Venezuela', 'Year': '2018', 'Total': '3.442401', 'Coal': '0.004177', 'Oil': '1.449721', 'Gas': '1.398248', 'Cement': '0.067426', 'Flaring': '0.522830', 'Other': '', 'ISO': 'VEN'}
# {'_id': ObjectId('64273cf8cfb518dff1f30e86'), 'Country': 'Venezuela', 'Year': '2019', 'Total': '3.075801', 'Coal': '0.005691', 'Oil': '1.199725', 'Gas': '1.189986', 'Cement': '0.061247', 'Flaring': '0.619152', 'Other': '', 'ISO': 'VEN'}
# {'_id': ObjectId('64273cf8cfb518dff1f30e87'), 'Country': 'Venezuela', 'Year': '2020', 'Total': '2.683968', 'Coal': '0.002292', 'Oil': '1.032570', 'Gas': '1.020079', 'Cement': '0.062281', 'Flaring': '0.566745', 'Other': '', 'ISO': 'VEN'}
# {'_id': ObjectId('64273cf8cfb518dff1f30e88'), 'Country': 'Venezuela', 'Year': '2021', 'Total': '2.827907', 'Coal': '0.001283', 'Oil': '1.071702', 'Gas': '1.146074', 'Cement': '0.062923', 'Flaring': '0.545925', 'Other': '', 'ISO': 'VEN'}
# {'_id': ObjectId('64273cf8cfb518dff1f30f94'), 'Country': 'Viet Nam', 'Year': '2017', 'Total': '2.478286', 'Coal': '1.150890', 'Oil': '0.663274', 'Gas': '0.190114', 'Cement': '0.454471', 'Flaring': '0.019537', 'Other': '', 'ISO': 'VNM'}
# {'_id': ObjectId('64273cf8cfb518dff1f30f95'), 'Country': 'Viet Nam', 'Year': '2018', 'Total': '2.889164', 'Coal': '1.420792', 'Oil': '0.735006', 'Gas': '0.195487', 'Cement': '0.522971', 'Flaring': '0.014908', 'Other': '', 'ISO': 'VNM'}
# {'_id': ObjectId('64273cf8cfb518dff1f30f96'), 'Country': 'Viet Nam', 'Year': '2019', 'Total': '3.560416', 'Coal': '1.998842', 'Oil': '0.796989', 'Gas': '0.197401', 'Cement': '0.551855', 'Flaring': '0.015329', 'Other': '', 'ISO': 'VNM'}
# {'_id': ObjectId('64273cf8cfb518dff1f30f97'), 'Country': 'Viet Nam', 'Year': '2020', 'Total': '3.403044', 'Coal': '1.989463', 'Oil': '0.675848', 'Gas': '0.175673', 'Cement': '0.548774', 'Flaring': '0.013286', 'Other': '', 'ISO': 'VNM'}
# {'_id': ObjectId('64273cf8cfb518dff1f30f98'), 'Country': 'Viet Nam', 'Year': '2021', 'Total': '3.344827', 'Coal': '2.016234', 'Oil': '0.621885', 'Gas': '0.140346', 'Cement': '0.555266', 'Flaring': '0.011096', 'Other': '', 'ISO': 'VNM'}
# {'_id': ObjectId('64273cf8cfb518dff1f310a4'), 'Country': 'Wallis and Futuna Islands', 'Year': '2017', 'Total': '2.148794', 'Coal': '0', 'Oil': '2.148794', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'WLF'}
# {'_id': ObjectId('64273cf8cfb518dff1f310a5'), 'Country': 'Wallis and Futuna Islands', 'Year': '2018', 'Total': '2.170616', 'Coal': '0', 'Oil': '2.170616', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'WLF'}
# {'_id': ObjectId('64273cf8cfb518dff1f310a6'), 'Country': 'Wallis and Futuna Islands', 'Year': '2019', 'Total': '2.189517', 'Coal': '0', 'Oil': '2.189517', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'WLF'}
# {'_id': ObjectId('64273cf8cfb518dff1f310a7'), 'Country': 'Wallis and Futuna Islands', 'Year': '2020', 'Total': '2.322550', 'Coal': '0', 'Oil': '2.322550', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'WLF'}
# {'_id': ObjectId('64273cf8cfb518dff1f310a8'), 'Country': 'Wallis and Futuna Islands', 'Year': '2021', 'Total': '2.392571', 'Coal': '0', 'Oil': '2.392571', 'Gas': '0', 'Cement': '0', 'Flaring': '0', 'Other': '', 'ISO': 'WLF'}
# {'_id': ObjectId('64273cf8cfb518dff1f311b4'), 'Country': 'Yemen', 'Year': '2017', 'Total': '0.352550', 'Coal': '0.010247', 'Oil': '0.274851', 'Gas': '0.019641', 'Cement': '0.022327', 'Flaring': '0.025483', 'Other': '', 'ISO': 'YEM'}
# {'_id': ObjectId('64273cf8cfb518dff1f311b5'), 'Country': 'Yemen', 'Year': '2018', 'Total': '0.340175', 'Coal': '0.010115', 'Oil': '0.272148', 'Gas': '0.006426', 'Cement': '0.021325', 'Flaring': '0.030162', 'Other': '', 'ISO': 'YEM'}
# {'_id': ObjectId('64273cf8cfb518dff1f311b6'), 'Country': 'Yemen', 'Year': '2019', 'Total': '0.402066', 'Coal': '0.011263', 'Oil': '0.320923', 'Gas': '0.006270', 'Cement': '0.021035', 'Flaring': '0.042575', 'Other': '', 'ISO': 'YEM'}
# {'_id': ObjectId('64273cf8cfb518dff1f311b7'), 'Country': 'Yemen', 'Year': '2020', 'Total': '0.376041', 'Coal': '0.008663', 'Oil': '0.289919', 'Gas': '0.006119', 'Cement': '0.020555', 'Flaring': '0.050785', 'Other': '', 'ISO': 'YEM'}
# {'_id': ObjectId('64273cf8cfb518dff1f311b8'), 'Country': 'Yemen', 'Year': '2021', 'Total': '0.378289', 'Coal': '0.007456', 'Oil': '0.290844', 'Gas': '0.006264', 'Cement': '0.020120', 'Flaring': '0.053605', 'Other': '', 'ISO': 'YEM'}
# {'_id': ObjectId('64273cf8cfb518dff1f312c4'), 'Country': 'Zambia', 'Year': '2017', 'Total': '0.395586', 'Coal': '0.109991', 'Oil': '0.236089', 'Gas': '0', 'Cement': '0.049506', 'Flaring': '0', 'Other': '', 'ISO': 'ZMB'}
# {'_id': ObjectId('64273cf8cfb518dff1f312c5'), 'Country': 'Zambia', 'Year': '2018', 'Total': '0.415569', 'Coal': '0.153866', 'Oil': '0.201936', 'Gas': '0', 'Cement': '0.059767', 'Flaring': '0', 'Other': '', 'ISO': 'ZMB'}
# {'_id': ObjectId('64273cf8cfb518dff1f312c6'), 'Country': 'Zambia', 'Year': '2019', 'Total': '0.421489', 'Coal': '0.127718', 'Oil': '0.241488', 'Gas': '0', 'Cement': '0.052283', 'Flaring': '0', 'Other': '', 'ISO': 'ZMB'}
# {'_id': ObjectId('64273cf8cfb518dff1f312c7'), 'Country': 'Zambia', 'Year': '2020', 'Total': '0.384656', 'Coal': '0.121080', 'Oil': '0.212805', 'Gas': '0', 'Cement': '0.050771', 'Flaring': '0', 'Other': '', 'ISO': 'ZMB'}
# {'_id': ObjectId('64273cf8cfb518dff1f312c8'), 'Country': 'Zambia', 'Year': '2021', 'Total': '0.394194', 'Coal': '0.126514', 'Oil': '0.218330', 'Gas': '0', 'Cement': '0.049349', 'Flaring': '0', 'Other': '', 'ISO': 'ZMB'}
# {'_id': ObjectId('64273cf8cfb518dff1f313d4'), 'Country': 'Zimbabwe', 'Year': '2017', 'Total': '0.650533', 'Coal': '0.400001', 'Oil': '0.218747', 'Gas': '0', 'Cement': '0.031785', 'Flaring': '0', 'Other': '', 'ISO': 'ZWE'}
# {'_id': ObjectId('64273cf8cfb518dff1f313d5'), 'Country': 'Zimbabwe', 'Year': '2018', 'Total': '0.783639', 'Coal': '0.476859', 'Oil': '0.269709', 'Gas': '0', 'Cement': '0.037070', 'Flaring': '0', 'Other': '', 'ISO': 'ZWE'}
# {'_id': ObjectId('64273cf8cfb518dff1f313d6'), 'Country': 'Zimbabwe', 'Year': '2019', 'Total': '0.723861', 'Coal': '0.448616', 'Oil': '0.238148', 'Gas': '0', 'Cement': '0.037097', 'Flaring': '0', 'Other': '', 'ISO': 'ZWE'}
# {'_id': ObjectId('64273cf8cfb518dff1f313d7'), 'Country': 'Zimbabwe', 'Year': '2020', 'Total': '0.676970', 'Coal': '0.428954', 'Oil': '0.211664', 'Gas': '0', 'Cement': '0.036351', 'Flaring': '0', 'Other': '', 'ISO': 'ZWE'}
# {'_id': ObjectId('64273cf8cfb518dff1f313d8'), 'Country': 'Zimbabwe', 'Year': '2021', 'Total': '0.706293', 'Coal': '0.451784', 'Oil': '0.218894', 'Gas': '0', 'Cement': '0.035615', 'Flaring': '0', 'Other': '', 'ISO': 'ZWE'}
# {'_id': ObjectId('64273cf8cfb518dff1f314e4'), 'Country': 'International Transport', 'Year': '2017', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'XIT'}
# {'_id': ObjectId('64273cf8cfb518dff1f314e5'), 'Country': 'International Transport', 'Year': '2018', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'XIT'}
# {'_id': ObjectId('64273cf8cfb518dff1f314e6'), 'Country': 'International Transport', 'Year': '2019', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'XIT'}
# {'_id': ObjectId('64273cf8cfb518dff1f314e7'), 'Country': 'International Transport', 'Year': '2020', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'XIT'}
# {'_id': ObjectId('64273cf8cfb518dff1f314e8'), 'Country': 'International Transport', 'Year': '2021', 'Total': '', 'Coal': '', 'Oil': '', 'Gas': '', 'Cement': '', 'Flaring': '', 'Other': '', 'ISO': 'XIT'}
# {'_id': ObjectId('64273cf8cfb518dff1f315f4'), 'Country': 'Global', 'Year': '2017', 'Total': '4.749682', 'Coal': '1.908857', 'Oil': '1.610910', 'Gas': '0.940144', 'Cement': '0.198416', 'Flaring': '0.051579', 'Other': '0.039776', 'ISO': 'WLD'}
# {'_id': ObjectId('64273cf8cfb518dff1f315f5'), 'Country': 'Global', 'Year': '2018', 'Total': '4.792753', 'Coal': '1.919213', 'Oil': '1.596350', 'Gas': '0.979965', 'Cement': '0.204225', 'Flaring': '0.053634', 'Other': '0.039366', 'ISO': 'WLD'}
# {'_id': ObjectId('64273cf8cfb518dff1f315f6'), 'Country': 'Global', 'Year': '2019', 'Total': '4.775633', 'Coal': '1.896468', 'Oil': '1.589920', 'Gas': '0.984878', 'Cement': '0.208309', 'Flaring': '0.056569', 'Other': '0.039490', 'ISO': 'WLD'}
# {'_id': ObjectId('64273cf8cfb518dff1f315f7'), 'Country': 'Global', 'Year': '2020', 'Total': '4.497423', 'Coal': '1.807760', 'Oil': '1.427353', 'Gas': '0.963695', 'Cement': '0.208844', 'Flaring': '0.051981', 'Other': '0.037789', 'ISO': 'WLD'}
# {'_id': ObjectId('64273cf8cfb518dff1f315f8'), 'Country': 'Global', 'Year': '2021', 'Total': '4.693699', 'Coal': '1.893923', 'Oil': '1.496614', 'Gas': '1.001585', 'Cement': '0.211472', 'Flaring': '0.052663', 'Other': '0.037443', 'ISO': 'WLD'}

# %%
#print all results to a dataframe
query = {'Year': {'$gte': '2017'}}
results = countries.find(query)
emissions2017_df = pd.DataFrame(results)

# %%
#check to make sure all rows were captured
print("Rows in DataFrame: ", len(emissions2017_df))
# Out:
# Rows in DataFrame:  1160

# %%
#export DataFrame to JSON
emissions2017_df.to_json(r'C:\Users\LTabl\OneDrive\Desktop\Project_03\data.json', indent = 1, orient = "columns")

# %%
#results = countries.find({})
#for i in range(17864):
    #pprint(results[i])
